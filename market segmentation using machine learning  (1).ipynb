# %% [markdown]
# Importing the Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Customer Data.csv")

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# Exploratory Data Analysis and Data Preprocessing

# %%
df.sample(5)
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5953  C16119  296.905944           1.000000      43.25              0.00
# 3138  C13228   56.091512           0.818182     405.00              0.00
# 2566  C12640  237.861439           1.000000     569.02            246.89
# 5813  C15976  212.306148           0.181818       0.70              0.70
# 2447  C12521  765.880394           0.909091       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5953                   43.25    875.310710             0.125000
# 3138                  405.00      0.000000             0.750000
# 2566                  322.13   1431.673728             0.500000
# 5813                    0.00   1922.593600             0.083333
# 2447                    0.00   1966.812413             0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5953                    0.000000                          0.125000
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
# filling mean value in place of missing values in the dataset
df['MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())
df['CREDIT_LIMIT']=df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# checking for duplicated rows 
df.duplicated().sum()
# Out:
# 0

# %%
# drop CUST_ID column because it is not used
df.drop(columns=["CUST_ID"],axis=1,inplace=True)

# %%
# KDE plot
plt.figure(figsize=(30,30))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %%
# Pairplot
selected = ['BALANCE', 'PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT']
sns.pairplot(df[selected])
plt.show()

# %%
# boxplot to detect outliers
num_cols = df.select_dtypes(include='number').columns
for col in num_cols:
    plt.figure(figsize=(6, 2.5))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.show()

# %%
# Outlier Detection and Removal 

# Select numeric columns only
numeric_cols = df.select_dtypes(include="number").columns

# Dictionary to store outlier counts
outlier_counts = {}

# Loop through each numeric column
for col in numeric_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Identify outliers
    outlier_mask = (df[col] < lower_bound) | (df[col] > upper_bound)
    outlier_counts[col] = int(outlier_mask.sum())

# Convert the result to a DataFrame and sort it
outliers_df = pd.DataFrame(list(outlier_counts.items()), columns=["Column", "Outlier Count"])
outliers_df = outliers_df.sort_values("Outlier Count", ascending=False).reset_index(drop=True)

# Display the result
print(outliers_df)
# Out:
#                               Column  Outlier Count
# 0                  BALANCE_FREQUENCY           1493
# 1                   PRC_FULL_PAYMENT           1474
# 2                             TENURE           1366
# 3                       CASH_ADVANCE           1030
# 4                   ONEOFF_PURCHASES           1013
# 5             INSTALLMENTS_PURCHASES            867
# 6                           PAYMENTS            808
# 7                          PURCHASES            808
# 8                   CASH_ADVANCE_TRX            804
# 9         ONEOFF_PURCHASES_FREQUENCY            782
# 10                  MINIMUM_PAYMENTS            774
# 11                     PURCHASES_TRX            766
# 12                           BALANCE            695
# 13            CASH_ADVANCE_FREQUENCY            525
# 14                      CREDIT_LIMIT            248
# 15               PURCHASES_FREQUENCY              0
# 16  PURCHASES_INSTALLMENTS_FREQUENCY              0

# %%
# capping for outlier 
numeric_cols = df.select_dtypes(include="number").columns

for col in numeric_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_cap = q1 - 1.5 * iqr
    upper_cap = q3 + 1.5 * iqr
    
    # Winsorise: values < lower_cap become lower_cap, values > upper_cap become upper_cap
    df[col] = df[col].clip(lower_cap, upper_cap)

# %%
# Heatmap for correlation 
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# Violin plots
spend_cols = ["PURCHASES", "ONEOFF_PURCHASES", "INSTALLMENTS_PURCHASES",
              "CASH_ADVANCE"]
for col in spend_cols:
    plt.figure(figsize=(6, 3))
    sns.violinplot(x=df[col])
    plt.title(f"Violin plot of {col}")
    plt.show()

# %% [markdown]
# Scaling the Dataframe

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()

# %%
scaled_df = sd.fit_transform(df)

# %% [markdown]
# PCA(Converting the DataFrame into 2D DataFrame for visualization)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.637715 -2.423495
# 1    -2.215350  2.245515
# 2     1.168272  0.275077
# 3    -0.523101 -0.209588
# 4    -1.657319 -1.642660
# ...        ...       ...
# 8945  0.671961 -2.533206
# 8946  0.207306 -1.605195
# 8947 -0.109551 -2.792296
# 8948 -2.075778 -2.292934
# 8949  0.524843 -0.692879
#
# [8950 rows x 2 columns]

# %% [markdown]
# Model Training and Evaluation

# %%
from sklearn.cluster import KMeans

# %%
# finding the value of k by using Elbow Method
inertia = []
range_val = range(1, 15)

for i in range_val:
    kmean = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmean.fit(scaled_df)  
    inertia.append(kmean.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(range_val, inertia, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.grid(True)
plt.show()

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
# Visualising the clustered dataframe
plt.figure(figsize=(10,10))
lx=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['green','red','black','yellow'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
# find all cluster centers
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])
# inverse transform the data
cluster_centers = sd.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0   483.245768          0.929216   706.892788       105.422185
# 1  3099.023451          0.967707   284.687581       164.888688
# 2  1855.816039          0.979447  2217.733137      1181.044548
# 3   825.130141          0.889470   259.102974       205.795767
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             535.732610   100.363077            0.857110
# 1             102.256629  2158.837497            0.221847
# 2             687.358906   416.815946            0.899415
# 3              45.702553   369.514355            0.189433
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.079872                         0.784177
# 1                   0.090838                         0.137309
# 2                   0.572525                         0.636606
# 3                   0.110040                         0.074949
#
# ...

# %%
# Creating a target column "Cluster" for storing the cluster segment
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40            0.0000
# 1     3202.467416           0.909091       0.00            0.0000
# 2     2495.148862           1.000000     773.17          773.1700
# 3     1666.670542           0.722223    1499.00         1443.5125
# 4      817.714335           1.000000      16.00           16.0000
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12            0.0000
# 8946    19.183215           1.000000     300.00            0.0000
# 8947    23.398673           0.833333     144.40            0.0000
# 8948    13.457564           0.833333       0.00            0.0000
# 8949   372.708075           0.722223    1093.25         1093.2500
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5     1809.828751           1.000000    1333.28               0.0
# 7     1823.652743           1.000000     436.20               0.0
# 10    1293.124939           1.000000     920.12               0.0
# 17      41.089489           0.722223     519.00               0.0
# 18    1989.072228           1.000000     504.35             166.0
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24               0.0
# 8942    40.829749           1.000000     113.28               0.0
# 8945    28.493517           1.000000     291.12               0.0
# 8946    19.183215           1.000000     300.00               0.0
# 8947    23.398673           0.833333     144.40               0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5                 1171.59375           0.0             0.666667
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    4942.927215           1.000000    1611.70              0.00
# 24    4942.927215           1.000000       0.00              0.00
# 28    4942.927215           1.000000     387.05            204.55
# 32    4942.927215           1.000000     324.95            324.95
# ...           ...                ...        ...               ...
# 8912   376.547421           0.857143     520.00            280.00
# 8914   181.891981           0.722223       0.00              0.00
# 8915   381.341657           1.000000      78.00              0.00
# 8917  1880.817982           1.000000       0.00              0.00
# 8941  4942.927215           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                    0.00000   2784.552848             0.000000
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000   773.1700          773.1700
# 6      627.260806           1.000000  2715.8725         1443.5125
# 12    1516.928620           1.000000  2715.8725         1443.5125
# 13     921.693369           1.000000  2137.9300          419.9600
# 21    4942.927215           1.000000  2715.8725         1443.5125
# ...           ...                ...        ...               ...
# 8758  1812.542545           0.857143  2715.8725         1443.5125
# 8801   275.020950           1.000000  1943.0000         1443.5125
# 8856   227.220411           1.000000  1387.6000          288.5400
# 8897   328.686581           1.000000  2715.8725         1443.5125
# 8923   486.661842           0.833333  1898.8800          939.0900
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                    0.00000      0.000000             1.000000
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40            0.0000
# 3     1666.670542           0.722223    1499.00         1443.5125
# 4      817.714335           1.000000      16.00           16.0000
# 8     1014.926473           1.000000     861.49          661.4900
# 9      152.225975           0.722223    1281.60         1281.6000
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40          734.4000
# 8943     5.871712           0.722223      20.90           20.9000
# 8944   193.571722           0.833333    1012.73         1012.7300
# 8948    13.457564           0.833333       0.00            0.0000
# 8949   372.708075           0.722223    1093.25         1093.2500
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %%
#Saving Scikitlearn models
import joblib
joblib.dump(kmeans_model, "kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']

# %%
cluster_df.to_csv("Clustered_Customer_Data.csv")

# %%
# Training and Testing the model accuracy using decision tree
#Split Dataset
from sklearn.model_selection import train_test_split
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
#Decision_Tree
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier(criterion="entropy")
dt.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
#Confusion_Matrix
from sklearn import metrics
from sklearn.metrics import classification_report
print(metrics.confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[573  12  27  27]
#  [  6 509  13  27]
#  [ 30   7 437  13]
#  [ 21  36   7 940]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90       639
#            1       0.90      0.92      0.91       555
#            2       0.90      0.90      0.90       487
#            3       0.93      0.94      0.93      1004
#
#     accuracy                           0.92      2685
#    macro avg       0.91      0.91      0.91      2685
# weighted avg       0.92      0.92      0.92      2685

# %%
# Saving the Decision tree model for future prediction
import pickle
filename = 'final_model.sav'
pickle.dump(dt, open(filename, 'wb'))
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result,'% Acuuracy')
# Out:
# 0.9206703910614525 % Acuuracy
